# %%
import json
import requests
api_keys = "e04aab4bebf7d42bb3baa3963a78d274"
url = "http://api.openweathermap.org/data/2.5/forecast"
query = {'q': 'Copenhagen,dk', 
         'mode': 'json',                       
         'units': 'metric',
         'appid': api_keys}
r = requests.get(url, params=query)

r.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1646751600,
#    'main': {'temp': 4.57,
#     'feels_like': 2.56,
#     'temp_min': 4.57,
#     'temp_max': 6.48,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1024,
#     'humidity': 77,
#     'temp_kf': -1.91},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 23},
#    'wind': {'speed': 2.31, 'deg': 310, 'gust': 2.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-03-08 15:00:00'},
#   {'dt': 1646762400,
#    'main': {'temp': 4.42,
#     'feels_like': 2.43,
#     'temp_min': 4.11,
#     'temp_max': 4.42,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1024,
#     'humidity': 74,
#     'temp_kf': 0.31},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
# ...
